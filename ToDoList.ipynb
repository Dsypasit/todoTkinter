# %%
import tkinter as tk

root=tk.Tk()               #create window
root.columnconfigure(0,weight=1)  
root.rowconfigure(0,weight=1)

frame1=tk.Frame(root)
frame1.grid(row=0,column=0,sticky='nsew')
frame1.columnconfigure(0,weight=1)
frame1.rowconfigure(0,weight=1)

listbox=tk.Listbox(frame1)
listbox.grid(row=0,column=0,padx=5,pady=5,sticky='nsew')

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

tk.Entry(root).grid(sticky='we')
root.grid_columnconfigure(0, weight=1)

root.mainloop()

# %% [markdown]
# #### date picker
# tkcalendar : pip install tkcalendar

# %%
# Import Required Library
from tkinter import *
from tkcalendar import Calendar # pip install tkcalendar
 
# Create Object
root = Tk()
 
# Set geometry
root.geometry("400x400")
 
# Add Calendar
cal = Calendar(root, selectmode = 'day',
               year = 2020, month = 5,
               day = 22)
 
cal.pack(pady = 20)
 
def grad_date():
    date.config(text = "Selected Date is: " + cal.get_date())
 
# Add Button and Label
Button(root, text = "Get Date",
       command = grad_date).pack(pady = 20)
 
date = Label(root, text = "")
date.pack(pady = 20)
 
# Execute Tkinter
root.mainloop()

# %%
import tkinter as tk
from tkcalendar import DateEntry

window = tk.Tk()

DateEntry(window, locale='en_US', date_pattern='mm/dd/y').pack()  # custom formatting
DateEntry(window, locale='en_US').pack()  # default formatting
window.mainloop()

# %% [markdown]
# #### message boxes

# %%
import tkinter
from tkinter import messagebox
top =  tkinter.Tk()
top.geometry("150x150")
messagebox.showinfo("Information","Information for user")
top.mainloop()

# %%
import tkinter
from tkinter import messagebox
top =  tkinter.Tk()
top.geometry("150x150")
messagebox.showwarning("Warning","Warning message for user")
top.mainloop()

# %%
import tkinter
from tkinter import messagebox
top =  tkinter.Tk()
top.geometry("150x150")
messagebox.showerror("Error","Error message for user")
top.mainloop()

# %%
from tkinter import *

# create window object
app = Tk()

# messagebox
def popup():
    return messagebox.askquestion("This is Popup!!","bello man")
    

# button
Button(app, text='Popup', command=popup).pack()


# start program
app.mainloop()

# %%
import tkinter
from tkinter import messagebox
top =  tkinter.Tk()
top.geometry("150x150")

# messagebox
def popup():
    return messagebox.askyesno("Application","Got it?")

top.mainloop()

# %%
import tkinter
from tkinter import messagebox
top =  tkinter.Tk()
top.geometry("150x150")
messagebox.askyesno("Application","Got it?")
top.mainloop()

# %%
import tkinter
from tkinter import *

top = tkinter.Tk()
top.title("Welcome to innovate app")
top.geometry("350x200")

labl = Label(top, text="Hello World!")
labl.grid(column=0, row=0)
txt = Entry(top, width=10)
txt.grid(column=1, row=0)

def click():
    labl.configure(text="Click me Button was clicked ! !")
    
btn = Button(top, text ="Click Me", command=click)
btn.grid(column=2, row=0)
    
top.mainloop()

# %% [markdown]
# #### get element in listbox

# %%
from tkinter import *

ws = Tk() 
ws.title('Python Guides') 
ws.geometry('400x300')

var = StringVar()

def showSelected():
    countries = []
    cname = lb.curselection()
    for i in cname:
        op = lb.get(i)
        countries.append(op)
    for val in countries:
        print(val)

show = Label(ws, text = "Select Your Country", font = ("Times", 14), padx = 10, pady = 10)
show.pack() 
lb = Listbox(ws, selectmode = "multiple")
lb.pack(padx = 10, pady = 10, expand = YES, fill = "both") 

x =["Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Australia", "Brazil", "Canada", "China", "Iceland", "Israel", "United States", "Zimbabwe"]

for item in range(len(x)): 
	lb.insert(END, x[item]) 
	lb.itemconfig(item, bg="#bdc1d6") 

Button(ws, text="Show Selected", command=showSelected).pack()
ws.mainloop()

# %% [markdown]
# #### status
# https://www.youtube.com/watch?v=MGu7zKi5azQ&list=PLCC34OHNcOtoC6GglhF3ncJ5rLwQrLGnV&index=10

# %%
from tkinter import *

root = Tk()

number_list = [1, 2, 3, 4, 5]

label1 = Label(root, text='bello')
label1.grid(row=0, column=1)
label2 = Label(root, text='hoya')
label2.grid(row=0, column=0)
label3 = Label(root, text='man')
label3.grid(row=0, column=2)
label4 = Label(root, text='dude')
label4.grid(row=0, column=3)

status = Label(root, text="your's task : " + str(len(number_list)), bd=1, relief=SUNKEN)
status.grid(row=1, column=0, columnspan=3, sticky=W+E)

root.mainloop()

# %% [markdown]
# #### checkboxes in listbox
# ttkwidgets : pip install ttkwidgets

# %%
import tkinter as tk
from ttkwidgets import CheckboxTreeview

root = tk.Tk()

tree = CheckboxTreeview(root)
tree.pack()

tree.insert("", "end", "1", text="1")
tree.insert("1", "end", "11", text="11")
tree.insert("1", "end", "12",  text="12")
tree.insert("11", "end", "111", text="111")
tree.insert("", "end", "2", text="2")

root.mainloop()

# %% [markdown]
# #### new windows

# %%
# This will import all the widgets
# and modules which are available in
# tkinter and ttk module
from tkinter import *
from tkinter.ttk import *
 
 
class NewWindow(Toplevel):
     
    def __init__(self, master = None):
         
        super().__init__(master = master)
        self.title("New Window")
        self.geometry("200x200")
        label = Label(self, text ="This is a new Window")
        label.pack()
 
 
# creates a Tk() object
master = Tk()
 
# sets the geometry of
# main root window
master.geometry("200x200")
 
label = Label(master, text ="This is the main window")
label.pack(side = TOP, pady = 10)
 
# a button widget which will
# open a new window on button click
btn = Button(master,
             text ="Click to open a new window")
 
# Following line will bind click event
# On any click left / right button
# of mouse a new window will be opened
btn.bind("<Button>",
         lambda e: NewWindow(master))
 
btn.pack(pady = 10)
 
# mainloop, runs infinitely
mainloop()

# %% [markdown]
# #### add list to listbox

# %%
 from tkinter import *

 strings= 'str1', 'str2', 'str3'

 listbox=Listbox(None)
 [listbox.insert(END, item) for item in strings]
 listbox.pack()
 
 listbox.insert(END, *strings)

# %%
from tkinter import *        
a= Tk()  
a.geometry("400x400")  
a.title("test")  
Lb1 = Listbox(a,bg = "pink", bd = 10, fg = "black",
                font = "Castellar", cursor = "target")  
Lb1.insert(1, "lion")  
Lb1.insert(2, "tiger")  
Lb1.insert(3, "zebra")  
Lb1.insert(4, "elephant")  
Lb1.insert(5, "deer")  
Lb1.insert(6, "fox")  
Lb1.insert(7, "Wolf")  
Lb1.insert(8, "Gorilla")  
Lb1.insert(9, "Jackal")  
Lb1.insert(10, "Otter")  
Lb1.pack()  
a.mainloop()

# %% [markdown]
# #### check to listbox

# %%
import tkinter
from tkinter import *

master = tkinter.Tk()
master.geometry("750x500")

listbox = Listbox(master)
listbox.place(x=3, y=0)

gui_state = {
    "one": {
        'button 1': BooleanVar(),
        'button 2': BooleanVar(),
        'button 3': BooleanVar(),
    },
    "two": {
        'button 1': BooleanVar(),
        'button 2': BooleanVar(),
        'button 3': BooleanVar(),
    },
    "three": {
        'button 1': BooleanVar(),
        'button 2': BooleanVar(),
        'button 3': BooleanVar(),
    },
    "four": {
        'button 1': BooleanVar(),
        'button 2': BooleanVar(),
        'button 3': BooleanVar(),
    },
}

for item in gui_state.keys():
    listbox.insert(END, item)


def bind_checkboxen(master, category):
    # render checkboxes for category. Mutate category when checkboxes are toggled.
    global checkboxes

    # delete old checkboxes
    for checkbox in checkboxes:
        checkbox.destroy()
    checkboxes = []

    x = 0

    # create new ones based on category fields
    for key in category.keys():
        checkbox = Checkbutton(master, text=key, variable=category[key])
        checkbox.place(x=300, y=0 + x)
        checkboxes.append(checkbox)
        x += 50


checkboxes = []


def onselect(evt):
    # Note here that Tkinter passes an event object to onselect()
    w = evt.widget
    index = int(w.curselection()[0])
    value = w.get(index)
    print('You selected item %d: "%s"' % (index, value))
    bind_checkboxen(master, gui_state[value])


listbox.bind('<<ListboxSelect>>', onselect)

mainloop()
# Out:
# You selected item 3: "four"

# %% [markdown]
# #### Notebook

# %%
import tkinter as tk
from tkinter import ttk

# root window
root = tk.Tk()
root.geometry('400x300')
root.title('Notebook Demo')

# create a notebook
notebook = ttk.Notebook(root)
notebook.pack(pady=10, expand=True)

# create frames
frame1 = ttk.Frame(notebook, width=400, height=280)
frame2 = ttk.Frame(notebook, width=400, height=280)

frame1.pack(fill='both', expand=True)
frame2.pack(fill='both', expand=True)

# add frames to notebook

notebook.add(frame1, text='General Information')
notebook.add(frame2, text='Profile')


root.mainloop()

# %% [markdown]
# #### menu

# %%
from tkinter import *

def donothing():
   filewin = Toplevel(root)
   button = Button(filewin, text="Do nothing button")
   button.pack()
   
root = Tk()
menubar = Menu(root)
filemenu = Menu(menubar, tearoff=0)
filemenu.add_command(label="New", command=donothing)
filemenu.add_command(label="Open", command=donothing)
filemenu.add_command(label="Save", command=donothing)
filemenu.add_command(label="Save as...", command=donothing)
filemenu.add_command(label="Close", command=donothing)

filemenu.add_separator()

filemenu.add_command(label="Exit", command=root.quit)
menubar.add_cascade(label="File", menu=filemenu)
editmenu = Menu(menubar, tearoff=0)
editmenu.add_command(label="Undo", command=donothing)

editmenu.add_separator()

editmenu.add_command(label="Cut", command=donothing)
editmenu.add_command(label="Copy", command=donothing)
editmenu.add_command(label="Paste", command=donothing)
editmenu.add_command(label="Delete", command=donothing)
editmenu.add_command(label="Select All", command=donothing)

menubar.add_cascade(label="Edit", menu=editmenu)
helpmenu = Menu(menubar, tearoff=0)
helpmenu.add_command(label="Help Index", command=donothing)
helpmenu.add_command(label="About...", command=donothing)
menubar.add_cascade(label="Help", menu=helpmenu)

root.config(menu=menubar)
root.mainloop()

# %% [markdown]
# #### GUI

# %% [markdown]
# ##### temp1

# %%
from tkinter import *
from tkinter import font 

# create window object
app = Tk()

# topic
topic_text = StringVar()
topic_label = Label(app, text='Topic', font=('Helvetica', 12), pady=20)
topic_label.grid(row=0, column=0, sticky=W)
topic_entry = Entry(app, textvariable=topic_text)
topic_entry.grid(row=0, column=1)

# detail
detail_text = StringVar()
detail_label = Label(app, text='Detail', font=('Helvetica', 12))
detail_label.grid(row=0, column=2, sticky=W)
detail_entry = Entry(app, textvariable=detail_text)
detail_entry.grid(row=0, column=3)

# listbox
listToDo = Listbox(app, height=8, width=50)
listToDo.grid(row=3, column=0, rowspan=6, columnspan=3, pady=20, padx=20)
# create scrollbar
scrollbar = Scrollbar(app)
scrollbar.grid(row=3, column=3)
# set scroll to listbox
listToDo.configure(yscrollcommand=scrollbar.set)
scrollbar.configure(command=listToDo.yview)

# buttons
add_btn = Button(app, text='Add List')

app.title('List-To-Do')
app.geometry('700x350')

# start program
app.mainloop()

# %% [markdown]
# ##### temp2

# %%
from tkinter import *
from tkinter.ttk import *

class NewWindow(Toplevel):
    
    def __init__(self, master = None):
         
        super().__init__(master = master)
        self.title("New Window")
        self.geometry("200x200")
        label = Label(self, text ="This is a new Window")
        label.pack()

# creates a Tk() object
master = Tk()



btn = Button(master, 
             text ="Click to open a new window")
btn.bind("<Button>",
         lambda e: NewWindow(master))
btn.grid(row=0, column=0, pady = 10)
             

# mainloop, runs infinitely
mainloop()

# %% [markdown]
# ##### temp3

# %%
from tkinter import *

class addWindow(Toplevel):
    
    def __init__(self, master = None):
         
        super().__init__(master = master)
        self.title("New Window")
        self.geometry("200x200")
        label = Label(self, text ="This is a new Window")
        label.pack()

# creates a Tk() object
master = Tk()

btn = Button(master, 
             text ="Click to open a new window")
btn.bind("<Button>",
         lambda e: addWindow(master))
btn.grid(row=0, column=0, pady = 10)
             
# mainloop, runs infinitely
mainloop()

# %% [markdown]
# ##### temp4

# %%
from tkinter import *

# class for new window add
class addWindow(Toplevel):
     
    def __init__(self, master = None):
         
        super().__init__(master = master)
        self.title("New Window")
        self.geometry("200x200")
        label = Label(self, text ="This is a new Window")
        label.pack()

def donothing():
   filewin = Toplevel(root)
   button = Button(filewin, text="Do nothing button")
   button.pack()

# create master window
master = Tk()
master.geometry("350x350")
master.title('TODODO')

# menubar
menubar = Menu(master)
acc_menu = Menu(menubar, tearoff=0)
acc_menu.add_command(label="New", command=donothing)
acc_menu.add_command(label="Open", command=donothing)
acc_menu.add_command(label="Save", command=donothing)
acc_menu.add_command(label="Exit", command=master.quit)

menubar.add_cascade(label="Account", menu=acc_menu)

# container: master(frame1)
frame1 = Frame(master)  
frame1.pack(padx=10, fill=BOTH, expand=True)      
frame1.columnconfigure(0,weight=1)
frame1.rowconfigure(0,weight=1) 

# label
acc = Label(frame1, text ="guest")
acc.grid(row=0, column=0,sticky='w')

# button add
btn_add = Button(frame1,
             text ="...")
btn_add.bind("<Button>",
         lambda e: addWindow(master))
btn_add.grid(row=0, column=1)

# container: master(frame2)
frame2 = Frame(master)                                 
frame2.pack(padx=10, fill=BOTH, expand=True)  
frame2.columnconfigure(0,weight=1)
frame2.rowconfigure(0,weight=1)

# create a listbox widget
listbox=Listbox(frame2)    
listbox.grid(row=0,column=0,sticky='nsew')
# create scrollbar
scrollbar = Scrollbar(frame2)
scrollbar.grid(row=0,column=1,sticky='nsew')
# set scroll to listbox
listbox.configure(yscrollcommand=scrollbar.set)
scrollbar.configure(command=listbox.yview)

# container: master(frame3)
frame3 = Frame(master)                                 
frame3.pack(padx=10, fill=BOTH, expand=True)
frame3.columnconfigure(0,weight=1)
frame3.rowconfigure(0,weight=1) 

# label status
status = Label(frame3, text ="have "+ str(3) + "list ")
status.grid(row=0, column=0, sticky='w')

# button add
btn_add = Button(frame3,
             text ="+")
btn_add.bind("<Button>",
         lambda e: addWindow(master))
btn_add.grid(row=0, column=1)

master.config(menu=menubar)
master.mainloop()

# %%
# importing tkinter module and Widgets
from tkinter import *
  
# Creating App class which will contain
class App:
    def __init__(self, master) -> None:
        
        # Instantiating master i.e toplevel Widget
        self.master = master
  
        # Creating first Label i.e with default font-size
        Label(self.master, text="I have default font-size").pack(pady=20)
  
        # Creating second label
        # This label has a font-family of Arial
        # and font-size of 25
        Label(self.master,
              text="I have a font-size of 25",
  
              # Changing font-size here
              font=("Arial", 25)
              ).pack()

# class for new window add
class addWindow(Toplevel):
     
    def __init__(self, master = None):
         
        super().__init__(master = master)
        self.title("New Window")
        self.geometry("200x200")
        label = Label(self, text ="This is a new Window")
        label.pack()
  
  
if __name__ == "__main__":
  
    # Instantiating top level
    root = Tk()
  
    # Setting the title of the window
    root.title("Change font-size of Label")
  
    # Setting the geometry i.e Dimensions
    root.geometry("400x250")
  
    # Calling our App
    app = App(root)
  
    # Mainloop which will cause this toplevel
    # to run infinitely
    root.mainloop()

# %%
import tkinter

LST_Couleurs = [ "black" , "red" , "green" , "yellow" , "blue" , "magenta" , "cyan" , "white" ]

def FNC_Selection ( ) :
    kindex = BOX_Temoin.curselection ( ) [ 0 ]
    LAB_Selection [ "text" ] = f"{ BOX_Temoin.get ( kindex ) } : sélectionnée."

    if BOX_Temoin.itemcget ( kindex , "background" ) != "" :
        LAB_LectureLigneFond [ "text" ] = "background : " + BOX_Temoin.itemcget ( kindex , "background" )
    else :
        LAB_LectureLigneFond [ "text" ] = "background : non modifiée"

    if BOX_Temoin.itemcget ( kindex , "foreground" ) != "" :
        LAB_LectureLigneTexte ["text" ] = "foreground : " + BOX_Temoin.itemcget ( kindex , "foreground" )
    else :
        LAB_LectureLigneTexte [ "text" ] = "foreground : non modifiée"

    if BOX_Temoin.itemcget ( kindex , "selectbackground" ) != "" :
        LAB_LectureSelectionFond [ "text" ] = "selectbackground : " + BOX_Temoin.itemcget ( kindex , "selectbackground" )
    else :
        LAB_LectureSelectionFond [ "text" ] = "selectbackground : non modifiée"

    if BOX_Temoin.itemcget ( kindex , "selectforeground" ) != "" :
        LAB_LectureSelectionTexte [ "text" ] = "selectforeground : " + BOX_Temoin.itemcget ( kindex , "selectforeground" )
    else :
        LAB_LectureSelectionTexte [ "text" ] = "selectforeground : non modifiée"

def FNC_GeneralFond ( ) :
    BOX_Temoin [ "background" ] = SPI_GeneralFond.get ( )

def FNC_LigneFond ( ) :
    BOX_Temoin.itemconfig ( BOX_Temoin.curselection ( ) [ 0 ] , background = SPI_LigneFond.get ( ) )

def FNC_LigneTexte ( ) :
    BOX_Temoin.itemconfig ( BOX_Temoin.curselection ( ) [ 0 ] , foreground = SPI_LigneTexte.get ( ) )

def FNC_SelectionFond ( ) :
    BOX_Temoin.itemconfig ( BOX_Temoin.curselection ( ) [ 0 ] , selectbackground = SPI_SelectionFond.get ( ) )

def FNC_SelectionTexte ( ) :
    BOX_Temoin.itemconfig ( BOX_Temoin.curselection ( ) [ 0 ] , selectforeground = SPI_SelectionTexte.get ( ) )

TKI_Principal = tkinter.Tk ( )
TKV_GeneralFond = tkinter.StringVar ( )
TKV_LigneFond = tkinter.StringVar ( )
TKV_LigneTexte = tkinter.StringVar ( )
TKV_SelectionFond = tkinter.StringVar ( )
TKV_SelectionTexte = tkinter.StringVar ( )

BUT_Quitter = tkinter.Button ( TKI_Principal , text = "Quitter" , command = TKI_Principal.destroy )
BOX_Temoin = tkinter.Listbox ( TKI_Principal , activestyle = "none" , selectmode = "single" , width = 14 )
SPI_GeneralFond = tkinter.Spinbox ( TKI_Principal , textvariable = TKV_GeneralFond , values = LST_Couleurs , width = 8 , wrap = True , command = FNC_GeneralFond )
SPI_LigneFond = tkinter.Spinbox ( TKI_Principal , textvariable = TKV_LigneFond , values = LST_Couleurs , width = 8 , wrap = True , command = FNC_LigneFond )
SPI_LigneTexte = tkinter.Spinbox ( TKI_Principal , textvariable = TKV_LigneTexte , values = LST_Couleurs , width = 8 , wrap = True , command = FNC_LigneTexte )
SPI_SelectionFond = tkinter.Spinbox ( TKI_Principal , textvariable = TKV_SelectionFond , values = LST_Couleurs , width = 8 , wrap = True , command = FNC_SelectionFond )
SPI_SelectionTexte = tkinter.Spinbox ( TKI_Principal , textvariable = TKV_SelectionTexte , values = LST_Couleurs , width = 8 , wrap = True , command = FNC_SelectionTexte )
LAB_Configuration = tkinter.Label ( TKI_Principal , text = "Modifier : w.itemconfig ()" , foreground = "blue" , font = ( None, 10 , "bold" ) )
LAB_EspaceGauche = tkinter.Label ( TKI_Principal , text = " " )
LAB_Selection = tkinter.Label (TKI_Principal , text = "..." , font = ( None , 10 , "italic" ) , width = 30 )
LAB_GeneralFond = tkinter.Label ( TKI_Principal , text = "Fond ..." , justify = "right" , anchor = "e" )
LAB_LigneFond = tkinter.Label ( TKI_Principal , text = "background" , justify = "right" , anchor = "e" )
LAB_LigneTexte = tkinter.Label ( TKI_Principal , text = "foreground" , justify = "right" , anchor = "e" )
LAB_SelectionFond = tkinter.Label ( TKI_Principal , text = "selectbackground" , justify = "right" , anchor = "e" )
LAB_SelectionTexte = tkinter.Label ( TKI_Principal , text = "selectforeground" , justify = "right" , anchor = "e" )
LAB_EspaceDroit = tkinter.Label ( TKI_Principal , text = " " )
LAB_Lecture = tkinter.Label ( TKI_Principal , text = "Lire : w.itemcget ()" , foreground = "green" , font = ( None , 10 , "bold" ) )
LAB_LectureLigneFond = tkinter.Label ( TKI_Principal , text = "background" , justify = "right" , anchor = "w" )
LAB_LectureLigneTexte = tkinter.Label ( TKI_Principal , text = "foreground" , justify = "right" , anchor = "w" )
LAB_LectureSelectionFond = tkinter.Label ( TKI_Principal , text = "selectbackground" , justify = "right" , anchor = "w" )
LAB_LectureSelectionTexte = tkinter.Label ( TKI_Principal , text = "selectforeground" , justify = "right" , anchor = "w" )

for i in range ( 10 ) : BOX_Temoin.insert ( "end" , f"Ligne d'index {i}" )

LAB_GeneralFond.grid ( row = 0 , column = 0 , sticky = "e" )
SPI_GeneralFond.grid ( row = 0 , column = 1 )
BOX_Temoin.grid ( row = 0 , column = 3 , rowspan = 7 , sticky = "nesw" )
LAB_Selection.grid ( row = 0 , column = 5 )
LAB_Configuration.grid ( row = 1 , column = 0 , columnspan = 2 )
LAB_EspaceGauche.grid ( row = 1 , column = 2 )
LAB_EspaceDroit.grid  ( row = 1 , column = 4 )
LAB_Lecture.grid ( row = 1 , column = 5 )
LAB_LigneFond.grid ( row = 2 , column = 0 , sticky = "e" )
SPI_LigneFond.grid ( row = 2 , column = 1 )
LAB_LectureLigneFond.grid ( row = 2 , column = 5 , sticky = "w" )
LAB_LigneTexte.grid ( row = 3 , column = 0 , sticky = "e" )
SPI_LigneTexte.grid ( row = 3 , column = 1 )
LAB_LectureLigneTexte.grid ( row = 3 , column = 5 , sticky = "w" )
LAB_SelectionFond.grid ( row = 4 , column = 0 , sticky = "e" )
SPI_SelectionFond.grid ( row = 4 , column = 1 )
LAB_LectureSelectionFond.grid ( row = 4 , column = 5 , sticky = "w" )
LAB_SelectionTexte.grid ( row = 5 , column = 0 , sticky = "e" )
SPI_SelectionTexte.grid ( row = 5 , column = 1 )
LAB_LectureSelectionTexte.grid ( row = 5 , column = 5 , sticky = "w" )
BUT_Quitter.grid ( row = 6 , column = 0 , sticky = "nesw" )

BOX_Temoin.bind ( "<ButtonRelease>" , lambda event : FNC_Selection ( ) )

TKV_GeneralFond.set ( "white" )
TKV_LigneFond.set ( "cyan" )
TKV_LigneTexte.set ( "blue" )
TKV_SelectionFond.set ( "yellow" )
TKV_SelectionTexte.set ( "red" )
BOX_Temoin.selection_set ( 0 )
FNC_GeneralFond ( )
FNC_Selection ( )

TKI_Principal.mainloop ( )

# %%
import tkinter as tk

root = tk.Tk()
custom_list = tk.Listbox(root)
custom_list.grid(row=0, column=0, sticky="news")

def onselect_listitem(event):
    w = event.widget
    index = int(w.curselection()[0])
    value = w.get(index)
    print(index, value, " color : ",custom_list.itemcget(index,'fg'))
    custom_list.itemconfig(index, fg='gray', selectforeground="gray")

custom_list.bind('<Double-Button-1>', onselect_listitem)

for k in range(20):
    custom_list.insert(k, " --------- " + str(k))

root.mainloop()
# Out:
# 1  --------- 1  color :
# 1  --------- 1  color :  gray
# 3  --------- 3  color :
# 3  --------- 3  color :  gray
# 3  --------- 3  color :  gray
# 3  --------- 3  color :  gray
# 3  --------- 3  color :  gray
# 4  --------- 4  color :
# 3  --------- 3  color :  gray
# 3  --------- 3  color :  gray
